# %% [markdown]
# ## Plot displacement time-series in a notebook
#
# This notebook calls `tsview.py` in PySAR for interactive time-series visualization. The corresponding command line usage is print out for the reference.

# %%
# %matplotlib notebook
import os
import matplotlib.pyplot as plt
from pysar.tsview import timeseriesViewer

# visualization functions
def tsview(fname, yx=None):
    """Plot input file using tsview.py script from PySAR"""
    cmd = 'tsview.py {} --ms 4 --noverbose'.format(fname)
    if yx is not None:
        cmd += ' --yx {} {}'.format(yx[0], yx[1])
    print(cmd)
    obj = timeseriesViewer(cmd)
    inps = obj.open()
    obj.figsize_img = [5, 4]
    obj.figsize_pts = [5, 2]
    obj.init_plot(inps)
    plt.show()
    return

# %%
# use FernandinaSenDT128 as the example dataset
proj_dir = os.path.expanduser('~/work/FernandinaSenDT128/PYSAR')
os.chdir(proj_dir)
tsview('timeseries_ECMWF_ramp_demErr.h5', yx=(216, 310))
# Out:
# tsview.py timeseries_ECMWF_ramp_demErr.h5 --ms 4 --noverbose --yx 216 310
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Try the tsview.py in command line in your terminal for more advanced / customized features.

# %%
# !tsview.py -h
# Out:
# usage: tsview.py [-h] [--label [FILE_LABEL [FILE_LABEL ...]]] [--ylim YMIN YMAX] [--tick-right] [-l LOOKUP_FILE]
#                  [--yx Y X] [--lalo LAT LON] [--ms MARKER_SIZE] [--ew EDGE_WIDTH] [-n NUM] [--error ERROR_FILE]
#                  [--start-date START_DATE] [--end-date END_DATE] [--exclude [EX_DATE_LIST [EX_DATE_LIST ...]]] [--zf]
#                  [--off OFFSET] [--noverbose] [-v VMIN VMAX] [-u UNIT] [--wrap] [--wrap-range MIN MAX] [--flip-lr]
#                  [--flip-ud] [--noflip] [--multilook-num NUM] [--nomultilook] [--alpha TRANSPARENCY] [-d DEM_FILE]
#                  [--dem-noshade] [--dem-nocontour] [--contour-smooth DEM_CONTOUR_SMOOTH] [--contour-step NUM]
#                  [--shade-az DEG] [--shade-alt DEG] [--shade-min MIN] [--shade-max MAX] [--shade-exag SHADE_EXAG]
#                  [--fontsize FONT_SIZE] [--fontcolor FONT_COLOR] [--nowhitespace] [--noaxis] [--notick] [-c COLORMAP]
# ...
