# %% [markdown]
# ### Example directory for GAMMA
#
#
# ```
# GalapagosEnvA2T061
# ├── GAMMA
# │   ├── geom_master
# │   │   ├── sim_20040207_4rlks.UTM_TO_RDC
# │   │   ├── sim_20040207_4rlks.diff_par
# │   │   ├── sim_20040207_4rlks.rdc.dem (or sim_150911_4rlks.hgt_sim)
# │   │   ├── sim_20040207_4rlks.utm.dem
# │   │   ├── sim_20040207_4rlks.utm.dem.par
# │   ├── interferograms
# │   │   ├── 20030329_20030503
# │   │   │   ├── 20030329_20030503_4rlks.base_perp    #generated by prep_gamma.py in PySAR
# │   │   │   ├── 20030329_20030503_4rlks.baseline     #generated by prep_gamma.py in PySAR
# │   │   │   ├── 20030329_20030503_4rlks.off
# │   │   │   ├── 20030329_4rlks.ramp.corner           #generated by prep_gamma.py in PySAR
# │   │   │   ├── 20030329_4rlks.ramp.corner_full      #generated by prep_gamma.py in PySAR
# │   │   │   ├── 20030329_4rlks.ramp.par
# │   │   │   ├── 20030503_4rlks.ramp.par
# │   │   │   ├── filt_20030329_20030503_4rlks.cor
# │   │   │   ├── diff_20030329_20030503_4rlks.unw
# │   │   ├── 20030329_20030607
# │   │   ...
# ├── PYSAR
#     └── GalapagosEnvA2T061.txt
# ```
